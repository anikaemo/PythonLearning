# %% [markdown]
# <a href="https://colab.research.google.com/github/anikaemo/PythonLearning/blob/main/ListDiconary_to_CreteDataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

anikaimo_cancer_csv_path = kagglehub.dataset_download('anikaimo/cancer-csv')
anikaimo_cancers_csv_path = kagglehub.dataset_download('anikaimo/cancers-csv')
anikaimo_screen_time_data_csv_path = kagglehub.dataset_download('anikaimo/screen-time-data-csv')

print('Data source import complete.')

# %%
#Import LIBRAY
import pandas as pd

# %%
#Empty df
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Berlin', 'Elrangen', 'Zurich']
city
# Out:
# ['Berlin', 'Elrangen', 'Zurich']

# %%
df = pd.DataFrame(city)
df
# Out:
#           0
# 0    Berlin
# 1  Elrangen
# 2    Zurich

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row,col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df = pd.DataFrame(city,columns =['City_in_Europe'])
df
# Out:
#   City_in_Europe
# 0         Berlin
# 1       Elrangen
# 2         Zurich

# %%
df = pd.DataFrame(city,columns =['City_in_Europe'] , index=['c1','c2','c3'])
df
# Out:
#    City_in_Europe
# c1         Berlin
# c2       Elrangen
# c3         Zurich

# %%
city2 = ['Dortmund', 'Paris', 'Potsdam']
df2 = pd.DataFrame(zip(city, city2), columns = ['city1','city2'])
df2
# Out:
#       city1     city2
# 0    Berlin  Dortmund
# 1  Elrangen     Paris
# 2    Zurich   Potsdam

# %%
df.shape
# Out:
# (3, 1)

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3 = [['Bavaria', 'Erlangen'], ['NRW','Dortmund']]
city3
# Out:
# [['Bavaria', 'Erlangen'], ['NRW', 'Dortmund']]

# %%
df4 = pd.DataFrame(city3, columns=['State','City'])
df4
# Out:
#      State      City
# 0  Bavaria  Erlangen
# 1      NRW  Dortmund

# %%
city
# Out:
# ['Berlin', 'Elrangen', 'Zurich']

# %%
city2
# Out:
# ['Dortmund', 'Paris', 'Potsdam']

# %%
dic1 = {
    'city1': city,
    'city2': city2
}
dic1
# Out:
# {'city1': ['Berlin', 'Elrangen', 'Zurich'],
#  'city2': ['Dortmund', 'Paris', 'Potsdam']}

# %%
df5 = pd.DataFrame(dic1)
df5
# Out:
#       city1     city2
# 0    Berlin  Dortmund
# 1  Elrangen     Paris
# 2    Zurich   Potsdam

# %%
type(dic1)
dic1
# Out:
# {'city1': ['Berlin', 'Elrangen', 'Zurich'],
#  'city2': ['Dortmund', 'Paris', 'Potsdam']}

# %%
#importing excel file
path = "/Screen Time Data.csv"
pd.read_csv(path)
df.head(500)
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...
